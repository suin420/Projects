# %% [markdown]
# # Reference Codes for Competition #1 #

# %%
# Data Wrangling
import pandas as pd
import numpy as np

# Hyperparameter Optimization
import optuna

# Modeling
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# Evaluation
from sklearn.metrics import accuracy_score

# Etc
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
X = pd.read_csv('X_train.csv')
y = pd.read_csv('y_train.csv').gender

# %%
X
# Out:
#             f0        f1        f2        f3        f4        f5        f6  \
# 0     1.065708 -1.108290  0.513177  0.458800 -0.747350 -0.428893 -0.539247
# 1    -1.118512 -0.283965 -0.807377 -0.227990  0.499381  0.517660  0.216804
# 2    -1.621164  0.359342 -0.009075  0.264630  0.613557  0.340367  0.289711
# 3     0.109638 -0.011408 -0.158151 -0.152665  0.118723  0.108297  0.011834
# 4    -0.947410 -0.471158  0.001532 -0.062487  0.147821  0.392181  0.105615
# ...        ...       ...       ...       ...       ...       ...       ...
# 3495 -1.464698  0.756092 -0.190608  0.345714 -0.504831 -0.024720 -0.562073
# 3496 -0.637022 -1.259685 -0.407535 -0.201414 -0.656503 -0.238687 -0.388249
# 3497 -1.917122  0.586596  0.176672 -0.022940  0.887222  0.212659  0.248100
# 3498 -1.613797  0.677287  0.720803 -0.153151  0.455676 -0.145414  0.168945
# 3499  1.958360 -0.180292  0.674883  0.694555 -0.852054 -0.690859  1.048080
#
#             f7        f8        f9  ...       f51       f52       f53  \
# 0    -0.731433  0.076911  0.021530  ... -0.113168  0.222601  0.002654
# 1    -0.090451  0.025904 -0.353093  ...  0.018257  0.148791  0.020114
# 2    -0.087876  0.157243  0.587353  ... -0.001830  0.121247 -0.187377
# 3     0.964645  0.056170 -0.055947  ...  0.225539  0.005191 -0.231734
# 4     0.027790 -0.491372 -0.168841  ...  0.053036  0.028679  0.028065
# ...        ...       ...       ...  ...       ...       ...       ...
# 3495  0.120787  0.344116 -0.068355  ... -0.027943  0.045253 -0.110824
# 3496  0.293272  0.295465  0.261209  ...  0.012746  0.158836 -0.051198
# 3497 -0.033524  0.439044  0.662337  ... -0.081378  0.040186 -0.095817
# 3498 -0.336686 -0.307792  1.001812  ... -0.095184 -0.097667  0.106476
# 3499 -0.055430  0.400252  1.064487  ... -0.156686  0.250758  0.040534
#
#            f54       f55       f56       f57       f58       f59       f60
# 0    -0.155161  0.207087  0.142654 -0.088473  0.046094  0.084016 -0.112096
# 1    -0.091960  0.096535  0.002544  0.067031 -0.033075 -0.102020 -0.230362
# 2    -0.045809 -0.031548 -0.013707  0.100588 -0.000918 -0.004412 -0.111499
# 3     0.000957  0.099028  0.065950  0.062079 -0.017500 -0.031968  0.026953
# 4     0.174117  0.116474 -0.036161  0.043683 -0.032832 -0.004160 -0.047245
# ...        ...       ...       ...       ...       ...       ...       ...
# 3495  0.165699 -0.003497  0.000216  0.127658 -0.027552 -0.003847 -0.081093
# 3496 -0.014381  0.062800 -0.012179  0.035542  0.019090 -0.031491  0.039452
# 3497 -0.072336 -0.003542 -0.015690 -0.126858  0.018467  0.007164  0.129033
# 3498 -0.039247  0.025189 -0.016424  0.038734  0.026754  0.005283 -0.042267
# 3499 -0.002391 -0.021110 -0.047117  0.158570  0.105143  0.184078  0.174920
#
# [3500 rows x 61 columns]

# %%
# 학습데이터(70%)와 평가데이터(30%) 생성
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# <font color="#CC3D3D"><p>
# ## DecisionTree

# %%
# 해당 estimator에 설정 가능한 파라미터와 디폴트 값을 나열
DecisionTreeClassifier().get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': 'deprecated',
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# ####  max_depth
# - 트리의 최대 깊이 지정
# - Default = 10
# - 지정된 값까지 tree깊이가 늘어나거나 노드가 가지는 데이터 수가 min_samples_split 보다 작아질때까지 계속 분할
#
# #### min_samples_split
# - 노드를 분할하기 위한 최소한의 샘플 데이터수 → 과적합을 제어하는데 사용
# - Default = 2 → 작게 설정할 수록 분할 노드가 많아져 과적합 가능성 증가
#
# #### min_samples_leaf
# - 리프노드가 되기 위해 필요한 최소한의 샘플 데이터수
# - min_samples_split과 함께 과적합 제어 용도
# - 불균형 데이터의 경우 특정 클래스의 데이터가 극도로 작을 수 있으므로 작게 설정 필요
#
# #### max_features
# - 최적의 분할을 위해 고려할 최대 feature 개수
# - Default = 'auto' (결정트리에서는 default가 none이었음)
# - int형으로 지정 →피처 갯수 / float형으로 지정 →비중
# - sqrt 또는 auto : 전체 피처 중 √(피처개수) 만큼 선정
# - log : 전체 피처 중 log2(전체 피처 개수) 만큼 선정
#
# #### max_leaf_nodes
# - 리프노드의 최대 개수

# %%
def objective_dt(trial):
    max_depth = trial.suggest_int('max_depth', 2, 20)  # 변경된 부분
    min_samples_split = trial.suggest_float('min_samples_split', 0.01, 0.5, log=True)
    min_samples_leaf = trial.suggest_float('min_samples_leaf', 0.01, 0.2, log=True)
    max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 2, 20)  # 변경된 부분
    dt_splitter = trial.suggest_categorical('splitter', ['best', 'random'])
    
    classifier_obj = DecisionTreeClassifier(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_leaf_nodes=max_leaf_nodes,
        class_weight='balanced',
        splitter=dt_splitter,
        random_state=0)
    
    score = cross_val_score(classifier_obj, X_train, y_train, scoring = 'accuracy', cv=5, n_jobs=-1)
    roc_auc = score.mean()
    return roc_auc 

study = optuna.create_study(sampler=optuna.samplers.TPESampler(seed=100), direction="maximize") 
study.optimize(objective_dt, n_trials=42)
    
print("Best score:", study.best_value)
print("Best parameters:", study.best_params)
# Out:
# [I 2023-04-11 16:05:31,081] A new study created in memory with name: no-name-7a70ae27-b868-43fd-a0c2-1b3e9c35342d
# [I 2023-04-11 16:05:31,251] Trial 0 finished with value: 0.603265306122449 and parameters: {'max_depth': 12, 'min_samples_split': 0.02971263961346909, 'min_samples_leaf': 0.03567057575132749, 'max_leaf_nodes': 18, 'splitter': 'random'}. Best is trial 0 with value: 0.603265306122449.
# [I 2023-04-11 16:05:31,470] Trial 1 finished with value: 0.643673469387755 and parameters: {'max_depth': 14, 'min_samples_split': 0.25298749738635706, 'min_samples_leaf': 0.015061193000286317, 'max_leaf_nodes': 12, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:31,706] Trial 2 finished with value: 0.6302040816326531 and parameters: {'max_depth': 5, 'min_samples_split': 0.015280201666902271, 'min_samples_leaf': 0.019312256807168915, 'max_leaf_nodes': 20, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:31,973] Trial 3 finished with value: 0.6310204081632653 and parameters: {'max_depth': 17, 'min_samples_split': 0.029217501512879038, 'min_samples_leaf': 0.03644685778704383, 'max_leaf_nodes': 19, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:32,219] Trial 4 finished with value: 0.6322448979591837 and parameters: {'max_depth': 5, 'min_samples_split': 0.04299623850507415, 'min_samples_leaf': 0.010171872754147916, 'max_leaf_nodes': 6, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:32,470] Trial 5 finished with value: 0.6004081632653062 and parameters: {'max_depth': 13, 'min_samples_split': 0.1061318660723781, 'min_samples_leaf': 0.013702515206142834, 'max_leaf_nodes': 9, 'splitter': 'random'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:32,703] Trial 6 finished with value: 0.6379591836734694 and parameters: {'max_depth': 20, 'min_samples_split': 0.012642694421264849, 'min_samples_leaf': 0.1440877257525416, 'max_leaf_nodes': 12, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:32,972] Trial 7 finished with value: 0.636734693877551 and parameters: {'max_depth': 13, 'min_samples_split': 0.010832419547997482, 'min_samples_leaf': 0.018760779427680344, 'max_leaf_nodes': 12, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:33,146] Trial 8 finished with value: 0.6220408163265306 and parameters: {'max_depth': 7, 'min_samples_split': 0.2806685080618631, 'min_samples_leaf': 0.1855721050177677, 'max_leaf_nodes': 18, 'splitter': 'random'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:33,317] Trial 9 finished with value: 0.5881632653061224 and parameters: {'max_depth': 8, 'min_samples_split': 0.037841903307607394, 'min_samples_leaf': 0.017048599516531857, 'max_leaf_nodes': 6, 'splitter': 'random'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:33,549] Trial 10 finished with value: 0.6379591836734694 and parameters: {'max_depth': 2, 'min_samples_split': 0.48362590693620966, 'min_samples_leaf': 0.08361943488938452, 'max_leaf_nodes': 15, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:33,786] Trial 11 finished with value: 0.6371428571428572 and parameters: {'max_depth': 20, 'min_samples_split': 0.1200167543200485, 'min_samples_leaf': 0.08991729288795654, 'max_leaf_nodes': 12, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:34,032] Trial 12 finished with value: 0.6379591836734694 and parameters: {'max_depth': 17, 'min_samples_split': 0.2296093539775841, 'min_samples_leaf': 0.1873126231658983, 'max_leaf_nodes': 9, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:34,316] Trial 13 finished with value: 0.6351020408163266 and parameters: {'max_depth': 20, 'min_samples_split': 0.07786908374454496, 'min_samples_leaf': 0.07427133446745598, 'max_leaf_nodes': 15, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:34,564] Trial 14 finished with value: 0.550204081632653 and parameters: {'max_depth': 16, 'min_samples_split': 0.16528507989480132, 'min_samples_leaf': 0.050537743006918434, 'max_leaf_nodes': 2, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:34,815] Trial 15 finished with value: 0.6302040816326531 and parameters: {'max_depth': 15, 'min_samples_split': 0.01670671164972908, 'min_samples_leaf': 0.11952108630395046, 'max_leaf_nodes': 15, 'splitter': 'best'}. Best is trial 1 with value: 0.643673469387755.
# [I 2023-04-11 16:05:35,047] Trial 16 finished with value: 0.6465306122448979 and parameters: {'max_depth': 10, 'min_samples_split': 0.30277836603340696, 'min_samples_leaf': 0.02699965480094374, 'max_leaf_nodes': 10, 'splitter': 'best'}. Best is trial 16 with value: 0.6465306122448979.
# [I 2023-04-11 16:05:35,268] Trial 17 finished with value: 0.6379591836734694 and parameters: {'max_depth': 10, 'min_samples_split': 0.4663371077284839, 'min_samples_leaf': 0.026694769622734173, 'max_leaf_nodes': 9, 'splitter': 'best'}. Best is trial 16 with value: 0.6465306122448979.
# [I 2023-04-11 16:05:35,469] Trial 18 finished with value: 0.5897959183673469 and parameters: {'max_depth': 10, 'min_samples_split': 0.295937997723931, 'min_samples_leaf': 0.025786352338119677, 'max_leaf_nodes': 6, 'splitter': 'random'}. Best is trial 16 with value: 0.6465306122448979.
# [I 2023-04-11 16:05:35,767] Trial 19 finished with value: 0.6440816326530612 and parameters: {'max_depth': 14, 'min_samples_split': 0.1628598770827231, 'min_samples_leaf': 0.010057107470951513, 'max_leaf_nodes': 14, 'splitter': 'best'}. Best is trial 16 with value: 0.6465306122448979.
# [I 2023-04-11 16:05:36,047] Trial 20 finished with value: 0.6440816326530612 and parameters: {'max_depth': 11, 'min_samples_split': 0.15725073959518482, 'min_samples_leaf': 0.010344371344646263, 'max_leaf_nodes': 14, 'splitter': 'best'}. Best is trial 16 with value: 0.6465306122448979.
# [I 2023-04-11 16:05:36,333] Trial 21 finished with value: 0.6375510204081631 and parameters: {'max_depth': 11, 'min_samples_split': 0.15040542636286738, 'min_samples_leaf': 0.010531269520507027, 'max_leaf_nodes': 14, 'splitter': 'best'}. Best is trial 16 with value: 0.6465306122448979.
# [I 2023-04-11 16:05:36,629] Trial 22 finished with value: 0.6232653061224489 and parameters: {'max_depth': 8, 'min_samples_split': 0.07520223960890625, 'min_samples_leaf': 0.012630628584820152, 'max_leaf_nodes': 16, 'splitter': 'best'}. Best is trial 16 with value: 0.6465306122448979.
# [I 2023-04-11 16:05:36,911] Trial 23 finished with value: 0.6428571428571429 and parameters: {'max_depth': 10, 'min_samples_split': 0.18816856528424722, 'min_samples_leaf': 0.02297619248080329, 'max_leaf_nodes': 10, 'splitter': 'best'}. Best is trial 16 with value: 0.6465306122448979.
# [I 2023-04-11 16:05:37,161] Trial 24 finished with value: 0.6485714285714286 and parameters: {'max_depth': 12, 'min_samples_split': 0.3790440712481509, 'min_samples_leaf': 0.045812572409335735, 'max_leaf_nodes': 13, 'splitter': 'best'}. Best is trial 24 with value: 0.6485714285714286.
# [I 2023-04-11 16:05:37,379] Trial 25 finished with value: 0.6485714285714286 and parameters: {'max_depth': 8, 'min_samples_split': 0.37084446973631724, 'min_samples_leaf': 0.057235870876731064, 'max_leaf_nodes': 11, 'splitter': 'best'}. Best is trial 24 with value: 0.6485714285714286.
# [I 2023-04-11 16:05:37,614] Trial 26 finished with value: 0.6485714285714286 and parameters: {'max_depth': 6, 'min_samples_split': 0.35502645271850786, 'min_samples_leaf': 0.05599947875768989, 'max_leaf_nodes': 7, 'splitter': 'best'}. Best is trial 24 with value: 0.6485714285714286.
# [I 2023-04-11 16:05:37,803] Trial 27 finished with value: 0.586938775510204 and parameters: {'max_depth': 5, 'min_samples_split': 0.3909012891024031, 'min_samples_leaf': 0.05556374835893596, 'max_leaf_nodes': 3, 'splitter': 'random'}. Best is trial 24 with value: 0.6485714285714286.
# [I 2023-04-11 16:05:38,040] Trial 28 finished with value: 0.6379591836734694 and parameters: {'max_depth': 2, 'min_samples_split': 0.3669398384082225, 'min_samples_leaf': 0.06380217166818775, 'max_leaf_nodes': 7, 'splitter': 'best'}. Best is trial 24 with value: 0.6485714285714286.
# [I 2023-04-11 16:05:38,245] Trial 29 finished with value: 0.5787755102040817 and parameters: {'max_depth': 7, 'min_samples_split': 0.21637533592634803, 'min_samples_leaf': 0.03951891174196232, 'max_leaf_nodes': 4, 'splitter': 'random'}. Best is trial 24 with value: 0.6485714285714286.
# [I 2023-04-11 16:05:38,495] Trial 30 finished with value: 0.6485714285714286 and parameters: {'max_depth': 4, 'min_samples_split': 0.3572243855446932, 'min_samples_leaf': 0.04141376152249869, 'max_leaf_nodes': 7, 'splitter': 'best'}. Best is trial 24 with value: 0.6485714285714286.
# [I 2023-04-11 16:05:38,713] Trial 31 finished with value: 0.6485714285714286 and parameters: {'max_depth': 4, 'min_samples_split': 0.3650545614438918, 'min_samples_leaf': 0.044225765428243115, 'max_leaf_nodes': 8, 'splitter': 'best'}. Best is trial 24 with value: 0.6485714285714286.
# [I 2023-04-11 16:05:38,946] Trial 32 finished with value: 0.6485714285714286 and parameters: {'max_depth': 4, 'min_samples_split': 0.3563912452048049, 'min_samples_leaf': 0.043455289145277846, 'max_leaf_nodes': 7, 'splitter': 'best'}. Best is trial 24 with value: 0.6485714285714286.
# [I 2023-04-11 16:05:39,165] Trial 33 finished with value: 0.6379591836734694 and parameters: {'max_depth': 3, 'min_samples_split': 0.4833393966034835, 'min_samples_leaf': 0.03136044336283335, 'max_leaf_nodes': 4, 'splitter': 'best'}. Best is trial 24 with value: 0.6485714285714286.
# [I 2023-04-11 16:05:39,432] Trial 34 finished with value: 0.6444897959183674 and parameters: {'max_depth': 6, 'min_samples_split': 0.25239560205041095, 'min_samples_leaf': 0.05972139414701708, 'max_leaf_nodes': 8, 'splitter': 'best'}. Best is trial 24 with value: 0.6485714285714286.
# [I 2023-04-11 16:05:39,686] Trial 35 finished with value: 0.6514285714285715 and parameters: {'max_depth': 4, 'min_samples_split': 0.33915445416669665, 'min_samples_leaf': 0.03910066841898059, 'max_leaf_nodes': 7, 'splitter': 'best'}. Best is trial 35 with value: 0.6514285714285715.
# [I 2023-04-11 16:05:39,919] Trial 36 finished with value: 0.6351020408163266 and parameters: {'max_depth': 4, 'min_samples_split': 0.11414872502381214, 'min_samples_leaf': 0.037552761848365354, 'max_leaf_nodes': 7, 'splitter': 'best'}. Best is trial 35 with value: 0.6514285714285715.
# [I 2023-04-11 16:05:40,168] Trial 37 finished with value: 0.6310204081632653 and parameters: {'max_depth': 4, 'min_samples_split': 0.21615159141350548, 'min_samples_leaf': 0.07346418415448747, 'max_leaf_nodes': 5, 'splitter': 'best'}. Best is trial 35 with value: 0.6514285714285715.
# [I 2023-04-11 16:05:40,435] Trial 38 finished with value: 0.6212244897959185 and parameters: {'max_depth': 3, 'min_samples_split': 0.056377403894385184, 'min_samples_leaf': 0.03462659241562533, 'max_leaf_nodes': 11, 'splitter': 'best'}. Best is trial 35 with value: 0.6514285714285715.
# [I 2023-04-11 16:05:40,625] Trial 39 finished with value: 0.5693877551020408 and parameters: {'max_depth': 6, 'min_samples_split': 0.3068628420619099, 'min_samples_leaf': 0.0310067656417212, 'max_leaf_nodes': 5, 'splitter': 'random'}. Best is trial 35 with value: 0.6514285714285715.
# [I 2023-04-11 16:05:40,895] Trial 40 finished with value: 0.6444897959183674 and parameters: {'max_depth': 6, 'min_samples_split': 0.20050888078378104, 'min_samples_leaf': 0.04838780343199705, 'max_leaf_nodes': 8, 'splitter': 'best'}. Best is trial 35 with value: 0.6514285714285715.
# [I 2023-04-11 16:05:41,143] Trial 41 finished with value: 0.6514285714285715 and parameters: {'max_depth': 4, 'min_samples_split': 0.32029012354271175, 'min_samples_leaf': 0.04457732966116829, 'max_leaf_nodes': 7, 'splitter': 'best'}. Best is trial 35 with value: 0.6514285714285715.
# Best score: 0.6514285714285715
# Best parameters: {'max_depth': 4, 'min_samples_split': 0.33915445416669665, 'min_samples_leaf': 0.03910066841898059, 'max_leaf_nodes': 7, 'splitter': 'best'}

# %%
model = DecisionTreeClassifier(**study.best_params, random_state=100)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.6685714285714286

# %% [markdown]
# # 0.6752380952380952
#
# max_depth = trial.suggest_int('max_depth', 2, 32)
#     min_samples_split = trial.suggest_float('min_samples_split', 0.01, 0.5, log=True)
#     min_samples_leaf = trial.suggest_float('min_samples_leaf', 0.01, 0.2, log=True)
#     max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 2, 32)
#     dt_splitter = trial.suggest_categorical('splitter', ['best', 'random'])
#
#     classifier_obj = DecisionTreeClassifier(
#         max_depth=max_depth,
#         min_samples_split=min_samples_split,
#         min_samples_leaf=min_samples_leaf,
#         max_leaf_nodes=max_leaf_nodes,
#         class_weight='balanced',
#         splitter=dt_splitter,
#         random_state=0)

# %%
# Insert HPO codes
#

# %% [markdown]
# <font color="#CC3D3D"><p>
# ## k-NN

# %%
KNeighborsClassifier().get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %% [markdown]
# #### n_neighbors : 검색할 이웃수, k
# - default = 5
#
#
# #### weights : 예측에 사용되는 가중치 함수
# - 'unjiform' : 균일한 가중치
# - 'distance' : 거리의 역수로 가중치 부여
#
#
# #### algorithm : 가장 가까운 이웃을 계산하는 데 사용하는 알고리즘
# - 'atuo', 'ball_tree', 'kd_tree', 'brute'
#
#
# #### p : Minkowski 메트릭에 대한 검정력 매개변수
# - default = 2
# - p=1 : 맨하튼거리
# - p=2 : 유클리드 거리
#
#
# #### metric : 거리 계산에 사용할 미터법
# - default = 'minkowski'

# %%
def objective_knn(trial):
    knn_n_neighbors = trial.suggest_int('n_neighbors', 1, 300, step=1)  
    knn_weights = trial.suggest_categorical('weights', ['uniform','distance'])
    knn_algorithms = trial.suggest_categorical('algorithm', ['auto', 'ball_tree', 'kd_tree', 'brute'])  
    knn_leaf_size = trial.suggest_int('leaf_size', 3, 7, step = 1) 
    knn_p = trial.suggest_int('p', 1, 3, step=1)  # 변경된 부분
    knn_metrics = trial.suggest_categorical('metric', ['minkowski', 'euclidean', 'manhattan', 'chebyshev'])  # 변경된 부분
    
    classifier_obj = KNeighborsClassifier(
        n_neighbors=knn_n_neighbors, 
        weights=knn_weights,
        algorithm=knn_algorithms,
        leaf_size=knn_leaf_size,
        p=knn_p,
        metric=knn_metrics
    )
    score = cross_val_score(classifier_obj, X_train, y_train, scoring = 'accuracy', cv=6, n_jobs=-1, error_score='raise')
    roc_auc = score.mean()
    return roc_auc

study = optuna.create_study(sampler=optuna.samplers.TPESampler(seed=100), direction="maximize") # 모르면 노터치, seed 값만 고정하면 항상 같은 값 !
study.optimize(objective_knn, n_trials=50)
    
print("Best score:", study.best_value)
print("Best parameters:", study.best_params)
# Out:
# [I 2023-04-11 16:14:03,673] A new study created in memory with name: no-name-f0d7341a-9bb0-4003-b3e9-2985a058aa9a
# [I 2023-04-11 16:14:04,317] Trial 0 finished with value: 0.6922491490483723 and parameters: {'n_neighbors': 164, 'weights': 'distance', 'algorithm': 'auto', 'leaf_size': 7, 'p': 1, 'metric': 'euclidean'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:06,674] Trial 1 finished with value: 0.6698028029467696 and parameters: {'n_neighbors': 33, 'weights': 'distance', 'algorithm': 'kd_tree', 'leaf_size': 5, 'p': 3, 'metric': 'minkowski'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:07,268] Trial 2 finished with value: 0.5991937932467201 and parameters: {'n_neighbors': 2, 'weights': 'distance', 'algorithm': 'kd_tree', 'leaf_size': 4, 'p': 1, 'metric': 'euclidean'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:07,853] Trial 3 finished with value: 0.6848962078719018 and parameters: {'n_neighbors': 174, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 6, 'p': 1, 'metric': 'manhattan'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:08,263] Trial 4 finished with value: 0.6771447576585645 and parameters: {'n_neighbors': 108, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 2, 'metric': 'chebyshev'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:11,292] Trial 5 finished with value: 0.6865371861866181 and parameters: {'n_neighbors': 284, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 3, 'p': 3, 'metric': 'minkowski'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:13,595] Trial 6 finished with value: 0.6685793102897231 and parameters: {'n_neighbors': 28, 'weights': 'distance', 'algorithm': 'kd_tree', 'leaf_size': 4, 'p': 3, 'metric': 'minkowski'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:14,004] Trial 7 finished with value: 0.6845006951435831 and parameters: {'n_neighbors': 90, 'weights': 'distance', 'algorithm': 'ball_tree', 'leaf_size': 4, 'p': 2, 'metric': 'euclidean'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:17,120] Trial 8 finished with value: 0.6824572127139364 and parameters: {'n_neighbors': 210, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 3, 'p': 3, 'metric': 'minkowski'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:17,526] Trial 9 finished with value: 0.6742832829953498 and parameters: {'n_neighbors': 82, 'weights': 'distance', 'algorithm': 'ball_tree', 'leaf_size': 4, 'p': 2, 'metric': 'manhattan'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:17,827] Trial 10 finished with value: 0.6853067021429599 and parameters: {'n_neighbors': 255, 'weights': 'distance', 'algorithm': 'brute', 'leaf_size': 7, 'p': 1, 'metric': 'euclidean'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:18,457] Trial 11 finished with value: 0.6653113364335138 and parameters: {'n_neighbors': 274, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 7, 'p': 2, 'metric': 'chebyshev'}. Best is trial 0 with value: 0.6922491490483723.
# [I 2023-04-11 16:14:19,292] Trial 12 finished with value: 0.6926606420889464 and parameters: {'n_neighbors': 218, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 6, 'p': 1, 'metric': 'euclidean'}. Best is trial 12 with value: 0.6926606420889464.
# [I 2023-04-11 16:14:19,591] Trial 13 finished with value: 0.6902036690796938 and parameters: {'n_neighbors': 198, 'weights': 'uniform', 'algorithm': 'brute', 'leaf_size': 6, 'p': 1, 'metric': 'euclidean'}. Best is trial 12 with value: 0.6926606420889464.
# [I 2023-04-11 16:14:20,434] Trial 14 finished with value: 0.6885826661552966 and parameters: {'n_neighbors': 142, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 6, 'p': 1, 'metric': 'euclidean'}. Best is trial 12 with value: 0.6926606420889464.
# [I 2023-04-11 16:14:21,294] Trial 15 finished with value: 0.6906161608897837 and parameters: {'n_neighbors': 225, 'weights': 'distance', 'algorithm': 'auto', 'leaf_size': 7, 'p': 1, 'metric': 'euclidean'}. Best is trial 12 with value: 0.6926606420889464.
# [I 2023-04-11 16:14:22,083] Trial 16 finished with value: 0.6881751681927866 and parameters: {'n_neighbors': 149, 'weights': 'distance', 'algorithm': 'auto', 'leaf_size': 6, 'p': 1, 'metric': 'euclidean'}. Best is trial 12 with value: 0.6926606420889464.
# [I 2023-04-11 16:14:22,408] Trial 17 finished with value: 0.6848982054109337 and parameters: {'n_neighbors': 238, 'weights': 'uniform', 'algorithm': 'brute', 'leaf_size': 7, 'p': 2, 'metric': 'euclidean'}. Best is trial 12 with value: 0.6926606420889464.
# [I 2023-04-11 16:14:22,851] Trial 18 finished with value: 0.6738777825718714 and parameters: {'n_neighbors': 180, 'weights': 'distance', 'algorithm': 'ball_tree', 'leaf_size': 6, 'p': 1, 'metric': 'chebyshev'}. Best is trial 12 with value: 0.6926606420889464.
# [I 2023-04-11 16:14:23,483] Trial 19 finished with value: 0.6889831727311951 and parameters: {'n_neighbors': 120, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 7, 'p': 2, 'metric': 'manhattan'}. Best is trial 12 with value: 0.6926606420889464.
# [I 2023-04-11 16:14:24,331] Trial 20 finished with value: 0.691435151892868 and parameters: {'n_neighbors': 187, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 1, 'metric': 'euclidean'}. Best is trial 12 with value: 0.6926606420889464.
# [I 2023-04-11 16:14:25,188] Trial 21 finished with value: 0.6930701375904884 and parameters: {'n_neighbors': 174, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 1, 'metric': 'euclidean'}. Best is trial 21 with value: 0.6930701375904884.
# [I 2023-04-11 16:14:26,037] Trial 22 finished with value: 0.6938851335155088 and parameters: {'n_neighbors': 161, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 1, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:26,882] Trial 23 finished with value: 0.688987167809259 and parameters: {'n_neighbors': 217, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 1, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:27,715] Trial 24 finished with value: 0.6828677069849944 and parameters: {'n_neighbors': 131, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 1, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:28,610] Trial 25 finished with value: 0.6881651804976269 and parameters: {'n_neighbors': 245, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 1, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:28,923] Trial 26 finished with value: 0.6885796698467487 and parameters: {'n_neighbors': 156, 'weights': 'uniform', 'algorithm': 'brute', 'leaf_size': 6, 'p': 2, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:29,536] Trial 27 finished with value: 0.682857719289835 and parameters: {'n_neighbors': 197, 'weights': 'uniform', 'algorithm': 'kd_tree', 'leaf_size': 4, 'p': 1, 'metric': 'manhattan'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:30,024] Trial 28 finished with value: 0.6685763139811752 and parameters: {'n_neighbors': 261, 'weights': 'uniform', 'algorithm': 'ball_tree', 'leaf_size': 6, 'p': 1, 'metric': 'chebyshev'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:30,934] Trial 29 finished with value: 0.6918386547773143 and parameters: {'n_neighbors': 300, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 1, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:31,829] Trial 30 finished with value: 0.6930711363600045 and parameters: {'n_neighbors': 164, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 2, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:32,649] Trial 31 finished with value: 0.6930711363600045 and parameters: {'n_neighbors': 164, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 2, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:33,524] Trial 32 finished with value: 0.6885816673857806 and parameters: {'n_neighbors': 169, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 2, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:34,418] Trial 33 finished with value: 0.6914371494318999 and parameters: {'n_neighbors': 159, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 2, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:35,250] Trial 34 finished with value: 0.6857221902615978 and parameters: {'n_neighbors': 102, 'weights': 'uniform', 'algorithm': 'kd_tree', 'leaf_size': 5, 'p': 2, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:38,196] Trial 35 finished with value: 0.6804177253623536 and parameters: {'n_neighbors': 68, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 4, 'p': 3, 'metric': 'minkowski'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:39,076] Trial 36 finished with value: 0.684912188184157 and parameters: {'n_neighbors': 133, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 2, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:39,733] Trial 37 finished with value: 0.6848962078719018 and parameters: {'n_neighbors': 174, 'weights': 'uniform', 'algorithm': 'kd_tree', 'leaf_size': 4, 'p': 3, 'metric': 'manhattan'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:40,562] Trial 38 finished with value: 0.684093197181073 and parameters: {'n_neighbors': 122, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 4, 'p': 2, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:43,661] Trial 39 finished with value: 0.6832732074084727 and parameters: {'n_neighbors': 195, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 3, 'metric': 'minkowski'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:44,084] Trial 40 finished with value: 0.6653183278201257 and parameters: {'n_neighbors': 52, 'weights': 'uniform', 'algorithm': 'ball_tree', 'leaf_size': 5, 'p': 2, 'metric': 'chebyshev'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:44,907] Trial 41 finished with value: 0.6893926682327373 and parameters: {'n_neighbors': 210, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 6, 'p': 1, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:45,758] Trial 42 finished with value: 0.6926636383974941 and parameters: {'n_neighbors': 160, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 6, 'p': 1, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:46,638] Trial 43 finished with value: 0.6930711363600045 and parameters: {'n_neighbors': 164, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 1, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:47,552] Trial 44 finished with value: 0.6893986608498331 and parameters: {'n_neighbors': 145, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 4, 'p': 2, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:48,402] Trial 45 finished with value: 0.6914371494318999 and parameters: {'n_neighbors': 178, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 1, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:49,312] Trial 46 finished with value: 0.6800092286303275 and parameters: {'n_neighbors': 111, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 2, 'metric': 'minkowski'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:49,609] Trial 47 finished with value: 0.6828746983716062 and parameters: {'n_neighbors': 133, 'weights': 'distance', 'algorithm': 'brute', 'leaf_size': 5, 'p': 1, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:50,949] Trial 48 finished with value: 0.6538884094795211 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'algorithm': 'kd_tree', 'leaf_size': 3, 'p': 1, 'metric': 'euclidean'}. Best is trial 22 with value: 0.6938851335155088.
# [I 2023-04-11 16:14:51,656] Trial 49 finished with value: 0.6865321923390382 and parameters: {'n_neighbors': 166, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 4, 'p': 3, 'metric': 'manhattan'}. Best is trial 22 with value: 0.6938851335155088.
# Best score: 0.6938851335155088
# Best parameters: {'n_neighbors': 161, 'weights': 'uniform', 'algorithm': 'auto', 'leaf_size': 5, 'p': 1, 'metric': 'euclidean'}

# %%
model = KNeighborsClassifier(**study.best_params)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.700952380952381

# %% [markdown]
# ## 0.7028571428571428
#
# knn_n_neighbors = trial.suggest_int('n_neighbors', 1, 300, step=1)
#     knn_weights = trial.suggest_categorical('weights', ['uniform','distance'])
#     knn_algorithms = trial.suggest_categorical('algorithm', ['auto', 'ball_tree', 'kd_tree', 'brute'])
#     knn_leaf_size = trial.suggest_int('leaf_size', 3, 7, step = 1)
#     knn_p = trial.suggest_int('p', 1, 3, step=1)  # 변경된 부분
#     knn_metrics = trial.suggest_categorical('metric', ['minkowski', 'euclidean', 'manhattan', 'chebyshev'])  # 변경된 부분
#
#     classifier_obj = KNeighborsClassifier(
#         n_neighbors=knn_n_neighbors,
#         weights=knn_weights,
#         algorithm=knn_algorithms,
#         leaf_size=knn_leaf_size,
#         p=knn_p,
#         metric=knn_metrics
#     )

# %%
# Insert HPO codes
#

# %%
# 실제 제출할 때 모델명은 "대표학생이름-차수.pickle"로 해야 함!!!

with open(file='이수인-3.pickle', mode='wb') as f:
    pickle.dump(model, f)

# %% [markdown]
# # End
